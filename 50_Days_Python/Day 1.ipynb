# %%
print("Hello")
# Out:
# Hello

# %%
print("My name is Ananya")
print(21)
print("I love cooking")
# Out:
# My name is Ananya
# 21
# I love cooking

# %%
name = "Ananya"
age = 21
like = "I love cooking"

print(name)
print(age)
print(like)
# Out:
# Ananya
# 21
# I love cooking

# %%
print("10")
# Out:
# 10

# %%
print(10)
# Out:
# 10

# %%
name = input("Enter the name:")
print("Hello", name)
# Out:
# Enter the name: anu
# Hello anu

# %%
name = input("Enter tha name:")
age = input("Enter the age: ")
college = input("Enter the college: ")

print(f"Hello {name} You are {age} from {college}")
# Out:
# Enter tha name: anu
# Enter the age:  20
# Enter the college:  svit
# Hello anu You are 20 from svit

# %%
name = input("Enter tha name:")
age = input("Enter the age: ")
college = input("Enter the college: ")

print("Hello", name, "You are", age,  "from", college)
# Out:
# Enter tha name: anu
# Enter the age:  20
# Enter the college:  svit
# Hello anu You are 20 from svit

# %%
p = float(input("Enter the value of p: "))
t = int(input("Enter the value of t: "))
r = int(input("Enter the value of r: "))

SI = (p * t * r) / 100

print(SI)
# Out:
# Enter the value of p:  10
# Enter the value of t:  21
# Enter the value of r:  2
# 4.2

# %%
#error because the datatype is int for t it won't take decimal values
p = float(input("Enter the value of p: "))
t = int(input("Enter the value of t: "))
r = int(input("Enter the value of r: "))

SI = (p * t * r) / 100

print(SI)
# Out:
# Enter the value of p:  12.0
# Enter the value of t:  12.433
# ------------------------------------------------
# ValueError     Traceback (most recent call last)
# Cell In[18], line 2
#       1 p = float(input("Enter the value of p: "))
# ----> 2 t = int(input("Enter the value of t: "))
#       3 r = int(input("Enter the value of r: "))
#       5 SI = (p * t * r) / 100
#
# ValueError: invalid literal for int() with base 10: '12.433'

# %%
p = float(input("Enter the value of p: "))
t = float(input("Enter the value of t: "))
r = float(input("Enter the value of r: "))

SI = (p * t * r) / 100

print(SI)
# Out:
# Enter the value of p:  12.093
# Enter the value of t:  23.643
# Enter the value of r:  12.343
# 35.29046364057

# %%
name = input("Enter the name:")
age = int(input("Enter age:"))
#print("Hello", name, "after 3 years you would be", age + 3, "years old")
print(f"Hello {name}, after 3 years you would be {age + 3} years old")
# Out:
# Enter the name: anu
# Enter age: 20
# Hello anu, after 3 years you would be 23 years old

# %%
a = int(input("Enter a: "))
b = int(input("Enter b" ))

sum = a + b
average = (a + b) / 2
product = a * b

print(sum, average, product)
# Out:
# Enter a:  2
# Enter b 3
# 5 2.5 6

# %%
name = input("Enter name:")
output = print(f"Hello {name.upper()}")
# Out:
# Enter name: anu
# Hello ANU

# %%
name = input("Enter name:")
output = f"Hello {name}"
print(output.upper())
# Out:
# Enter name: anu
# HELLO ANU

# %%
name = input("Enter name: ")
print(f"Hello {name.upper()}")
# Out:
# Enter name:  anu
# Hello ANU

# %%
name = input("Enter full name: ")

print("UPPER:", name.upper())
print("LOWER:", name.lower())
print("TITLE:", name.title())
# Out:
# Enter full name:  ananya
# UPPER: ANANYA
# LOWER: ananya
# TITLE: Ananya

# %%
mark = int(input("Enter number: "))
if mark > 40:
        print("Pass")
else:
        print("Fail")
# Out:
# Enter number:  54
# Pass
