# %%
#Use len(), max(), min(), sum() on a list of 5 numbers — print all results
list = [1,4,7,3,9]

# %%
len(list)
# Out:
# 5

# %%
max(list)
# Out:
# 9

# %%
min(list)
# Out:
# 1

# %%
sum(list)
# Out:
# 24

# %%
#Take a string input → print it in uppercase, lowercase, and title case using string methods
input = 'Artificial intelligence'
print(input.upper())
# Out:
# ARTIFICIAL INTELLIGENCE

# %%
print(input.lower())
# Out:
# artificial intelligence

# %%
print(input.title())
# Out:
# Artificial Intelligence

# %%
#Generate a random number between 1–100 and check if it's even or odd
import random
number = random.randint(1,100)
print(number)
if number % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# 26
# even

# %%
#Use math module to find: square root, ceiling, floor, and power of a number taken from user
import math

# %%
math.sqrt(64)
# Out:
# 8.0

# %%
math.ceil(7.3)
# Out:
# 8

# %%
math.floor(7.9)
# Out:
# 7

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
#Use os module to print current directory and list all files in it
import os

print(os.getcwd())

print(os.listdir())
# Out:
# C:\Users\Ananya\Desktop\AI&ML Journey\50_days_Python
# ['.ipynb_checkpoints', 'Day1.ipynb', 'Day2.ipynb']

# %%
#. Create two lists [1,2,3,4] and ['a','n','b','c'] → zip them → convert to a dictionary
key = [1, 2, 3, 4]
values = ('a', 'n', 'b', 'd')

zipped = zip(key, values)
dictionary = dict(zipped)

print(dictionary)
# Out:
# {1: 'a', 2: 'n', 3: 'b', 4: 'd'}
